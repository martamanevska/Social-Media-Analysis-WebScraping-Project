# %% [markdown]
# ##### Social Media Analytics
# ### Introduction to Text Mining
# ## Keywords extraction (using RAKE method)
# (c) Nuno Antonio 2019-2022 v1.02

# %% [markdown]
# ### Initial setup

# %%
# Import packages
import csv
import pandas as pd
import numpy as np
import nltk
import re
from nltk.tokenize import word_tokenize
import re
from bs4 import BeautifulSoup
from rake_nltk import Rake
# Out:
# C:\Users\User\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Load dataset
# Load dataset
ds = pd.read_parquet("sputnik.parquet.snappy", engine='fastparquet')

# Define the desired data types
dtypes = {'title': 'category', 'author': 'category', 'date': 'datetime64[ns]', 'text': 'category', 'comments': 'object'}

# Convert columns to specified data types
ds['date'] = pd.to_datetime(ds['date'])  # Convert 'date' column to datetime

ds = ds.astype(dtypes)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Load dataset
#       2 # Load dataset
# ----> 3 ds = pd.read_parquet("sputnik.parquet.snappy", engine='fastparquet')
#       5 # Define the desired data types
#       6 dtypes = {'title': 'category', 'author': 'category', 'date': 'datetime64[ns]', 'text': 'category', 'comments': 'object'}
#
# File ~\anaconda3\lib\site-packages\pandas\io\parquet.py:503, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     456 """
#     457 Load a parquet object from the file path, returning a DataFrame.
#     458
#    (...)
#     499 DataFrame
#     500 """
#     501 impl = get_engine(engine)
# --> 503 return impl.read(
#     504     path,
#     505     columns=columns,
#     506     storage_options=storage_options,
#     507     use_nullable_dtypes=use_nullable_dtypes,
#     508     **kwargs,
#     509 )
#
# File ~\anaconda3\lib\site-packages\pandas\io\parquet.py:351, in FastParquetImpl.read(self, path, columns, storage_options, **kwargs)
#     344         parquet_kwargs["open_with"] = lambda path, _: fsspec.open(
#     345             path, "rb", **(storage_options or {})
#     346         ).open()
#     347 elif isinstance(path, str) and not os.path.isdir(path):
#     348     # use get_handle only when we are very certain that it is not a directory
#     349     # fsspec resources can also point to directories
#     350     # this branch is used for example when reading from non-fsspec URLs
# --> 351     handles = get_handle(
#     352         path, "rb", is_text=False, storage_options=storage_options
#     353     )
#     354     path = handles.handle
#     356 try:
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:865, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#    (...)
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
# --> 865         handle = open(handle, ioargs.mode)
#     866     handles.append(handle)
#     868 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sputnik.parquet.snappy'

# %%
# Drop non-English reviews
ds = ds.drop(ds[ds.Language!='English'].index)

# %% [markdown]
# ### Functions

# %%
# Text preprocessing
def textPreProcess(rawText, removeHTML=True, charsToRemove=r"\?|\.|\!|\;|\.|\"|\,|\(|\)|\&|\:|\|[0-9]|--| [ ] |'s |said|says|also|according|Ukrainian|Ukraine|US|Russian|Russia|would", removeNumbers=True, removeLineBreaks=False, specialCharsToRemove=r'[^\x00-\xfd]', convertToLower=True, removeConsecutiveSpaces=True):
    if type(rawText) != str:
        return rawText
    procText = rawText
        
    # Remove HTML
    if removeHTML:
        procText = BeautifulSoup(procText,'html.parser').get_text()

    # Remove punctuation and other special characters
    if len(charsToRemove)>0:
        procText = re.sub(charsToRemove,' ',procText)

    # Remove numbers
    if removeNumbers:
        procText = re.sub(r'\d+',' ',procText)

    # Remove line breaks
    if removeLineBreaks:
        procText = procText.replace('\n',' ').replace('\r', '')

    # Remove special characters
    if len(specialCharsToRemove)>0:
        procText = re.sub(specialCharsToRemove,' ',procText)

    # Normalize to lower case
    if convertToLower:
        procText = procText.lower() 

    # Replace multiple consecutive spaces with just one space
    if removeConsecutiveSpaces:
        procText = re.sub(' +', ' ', procText)
        
    # Remove stop words
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(procText)
    filtered_text = [word for word in word_tokens if word.casefold() not in stop_words]
    procText = ' '.join(filtered_text)

    return procText

# %%
# Tokenize words
def tokenize_words(words):
    if (type(words) != str) or (word_tokenize(words) == ''):
        return np.nan
    else:
        return word_tokenize(words)

# %%
# Function to create text from words
def recreateText(words):
    if type(words) == list:
        temp_str = (' ').join(words)
        return temp_str
    else:
        return np.nan

# %% [markdown]
# ### Analysis

# %%
# Create a dataframe with only the description
processedReviews = pd.DataFrame(data=ds.RevDescription.apply(textPreProcess,charsToRemove ='', removeNumbers=False).values, index=ds.index, columns=['PreProcessedText'])
# Out:
# /Users/nunoantonio/opt/anaconda3/lib/python3.8/site-packages/bs4/__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(

# %%
# Remove rows with empty text
processedReviews.PreProcessedText = processedReviews.PreProcessedText.str.strip()
processedReviews = processedReviews[processedReviews.PreProcessedText != '']

# %%
# Find specific terms
termsToSearch = ['hygiene', 'clean', 'safe']
searchList =  re.compile('|'.join(termsToSearch))

# Get words from sentences
listOfWords =  processedReviews.PreProcessedText.apply(tokenize_words)

# Reconstruct sentences with spaces in the beginning and in the end
ppText = listOfWords.apply(recreateText)

# Look for search terms in sentences and present them
ppText_searched=[]
for review in ppText:
    if searchList.search(' '+ review +' '):
        ppText_searched.append(review)

# %%
# The first 3 reviews
# termsToSearch = ['hygiene', 'clean', 'safe']
ppText_searched[0:3]
# Out:
# ['hotel was clean and the staff helpful and friendly generally noisy , no atmosphere and further from the beach than it originally looked on the photos . the bar and and reception area lacking in any sort of atmosphere .',
#  'an excellent hotel lovely breakfast clean towels every day our room was cleaned every day',
#  'good clean hotel , in great location . a room overlooking the beach gave a beautiful outlook . ordinary breakfast']

# %%
# RAKE method - in English
r = Rake(language='english')

# %%
# Keywords extraction per review
r.extract_keywords_from_sentences(processedReviews['PreProcessedText'])
r.get_ranked_phrases()
# Out:
# ['para um hotel 4 estrelas estão muito mal servidos de louça e têm um grave problema de formigas',
#  'categories arecipriani venicevilla cimbrone ravello italycopocabana beach rio de janeirolizard island australiaice hotel kiruna swedenpera palace istanbulso',
#  'pao ok ... mas por favor fiambre de peru e otros ... sao de muita muita fraca qualidade',
#  'muy muy buenos !!! las camas suplementarias que nos dieron estaban en el salon de la primera planta',
#  'por fin un hotel con difusor para el secador ... las que tenéis el pelo rizado',
#  'un petit peu de laisser aller du jeune personnel et des toilettes pas nettoyées',
#  'accès direct à la plage et grande amabilité du personnel discret et à disposition du client',
#  'ainsi si vous voulez vous rendre en ville cela vous coûtera 60 euros',
#  'el tamaño de los apartamentos los servicios son limitados para familias con niños',
#  'birthday great suprise clean rooms happy staff friendly staff great food exceptional puddings amazing housekeeping large rooms lovely pool plenty sunbeds great gardens nice pooltable area',
#  'comida era fraca e com pouca variedade de uns dias para os outros',
#  'stay1 rpt1 portuguese2 rpt2 portuguese3 sic portuguese4 tvi portuguese5 bbc1',
#  'tastes example one night beef pork roast ham turkey fish salmon tuna steak sardines swordfish steaks plus pasta dishes cold meats stroganoff',
#  'galery ... paintings ... breakfast .... noise ... quality .. timetable .. swimmingpool ... mediocre askinng',
#  'avait une très mauvaise odeur dans la salle de bain',
#  'erityisesti alakerran baari oli mukava paikka jossa pieni kirjasto',
#  'appartement rien ne manque dans la cuisine le calme du lieu',
#  'nous sommes allé parlé de nos déceptions à la réception',
#  'mais la ville la plus proche est à 20 minutes et l',
#  'mais ils semblaient en avoir vraiment rien à faire',
#  'aucun spa et les 2 bains turques étaient brisés ...',
#  'rendre ce qui est étonnant pour un hôtel 5 étoiles',
#  'qualidade nao fornecem toalhas para uso nas piscinas',
#  'entenderéis ..... :-) calidad precio el hotel está muy bien',
#  'high summerevening meal 1 star ratingduty manager words mean nothingmost staff need',
#  'amazing location // perfect breakfast // always helpful staff // long breakfast hours',
#  'cuéntanos lo que te gustó más de tu estancia',
#  'esto es un incoveniente para niños pequeños !!,',
#  'prainha clube ligt aan het mooiste strand van de algarve',
#  'ceiling crystals constantly chime making everything sound like banging wine bottles together',
#  'excellent location beautiful sea view lovely beach fabulous restaurant great outdoor seating areas beautiful pool excellent food',
#  'la piscine atlantique et la plage des 3 irmaos',
#  'jean paul gaultier limited edition worth £ 180 ). came back',
#  'padrao dos descobrimentos .( monument der ontdekkingen ). ate',
#  'good points friendly staffmodern hotelgood location near beachgreat breakfastsparkling wine',
#  'de appartementen zijn echt aan een opknapbeurt toe',
#  'un seul restaurant dans cet hôtel cinq étoile',
#  'juillet et aout sont ils encore agréables',
#  'ligt vasco da gama begraven ), torre de belem',
#  'need ... massive pool ... nice cocktail hour .. great breakfast ... prob best suited',
#  'room ... cleaned every day ,,, fresh towels every day ... breakfast ,, great',
#  'staff lovely location good metro right outside breakfast good wee bar really friendly staff would',
#  'los hoteles de la zona de calidad similar',
#  'est toujours le meme enchantement .: le site',
#  'suites familiares são muito confortáveis e bem decoradas',
#  'sausages proper job ... fresh eggs .. pancakes .. fantastic ... position great ..',
#  'small children pool 7ft wide .. 18in inches deep approx',
#  'driver ), drop along av fontes pereria de melo',
#  'en pleno paseo de la playa de rocha',
#  'mr paulo braz made us terrific delicious passion fruit margarita cocktail',
#  'keeping everything spic n span ???? fabalous hotel definatley',
#  'location luke warm shower water noisy air con omelette delay need stronger wifi',
#  'good facilities ... swimming pools ... gardens ... spa ... lovely coastal walks',
#  'proximité du centre de location de la voiture',
#  'el trato recibido por el personal del checking',
#  'bed comfortable .. parking free bad situation .. metro far away .. room',
#  'beautiful place olsos de aguia porto bay falesia hotel',
#  'le wifi ne fonctionne pas du tout',
#  'bar nearby friendly staff breakfast selection good choice cleanliness external pool lovely taxis',
#  'except torre de belèm ). tramline 28 stops',
#  'car park servicing noisy nearby apartments ... avoid 127 !!)...',
#  'excellent sound insulation muffles traffic noise successf ... see',
#  'excellent week ... weather brill ... accommodation excellent .... staff excellent ...',
#  'moment special 2for1 amizing outdoor pool covered across road',
#  'pequeno almoço era muito simpático e disponivel',
#  'door every 20 minutes airport 45 minutes peaceful surroundings room large bed',
#  'room comfortable bed amazing staff good wifi free car park lovely breakfast',
#  'big spacious good quality decoration side sea view room facing hotel jupiter',
#  'great breakfast selectionwe paid buffet dinner 3 times good quality',
#  '3 euros per cup plus 3 euros service charge per person',
#  'great time nothing major ... pool needs refurb ... things look old',
#  'well appointed stocked mini bar underground car park great breakfast nothing negative',
#  'il est bien situé à cause qu',
#  'stander twin bed "( two single bed putting together',
#  'café da manhã é mto bom !! e',
#  'return ... obrigado por uma estadia maravilhosa',
#  'making simple tasks like getting poll towels quite time consuming',
#  'los desayunos son muy muy pobres',
#  'clean .. barfood excellent ... bararea lovely spacious',
#  'le seul hôtel dans les environs',
#  'staff absolutely charming ... beautiful views ... fab breakfast ... nothing',
#  'comfort ???????? decor ?????? service ?????? value ??????',
#  'great location .. helpful friendly staff super breakfast decent bar shower',
#  'room !! would definitely recommend !! playa de rocha',
#  'aged bain marie emits lovely gas fumes',
#  'love scrambled eggs becon n beans hehe missing',
#  'vista da varanda dá diretamente para',
#  'serving staff worked hards pool area nice lovely views',
#  'charcuterie ... faz medo ... fruta ok',
#  '3rd reported occasion ), old fashioned analogue tube tvs',
#  'avait les menus avant que quelqu',
#  'cleaned every day fresh towels every day beds lovely ..',
#  'large room super view good porter service reception staff quite surly',
#  'location alongside metro station good breakfast poor evevning restaurant',
#  'helpfull staff free parking ok gym short swimming pool opening time',
#  'beautiful palaces ). lisbon card gives free transportation including train',
#  'despite paying half board ate oit last 4 nights',
#  'nous allons à prainha et c',
#  'great locationvery clean spacious roomsprime locationvery friendly',
#  'great location .. lovely bright clean room .. great view',
#  'modern clean great staff good breakfast 20 plus mins walk',
#  'las calidades de los apartamentos',
#  'deserve gold star twice daily cleaning change towels rubbish removal',
#  'con una pequeña zona de cocina',
#  'praia dos 3 irmaos ). kitchen equipped well enough',
#  'rua de escola politecnica menu del dia',
#  'subway outside hotel ). jardim da fundação calouste gulbenkian',
#  'english speaking movie channel ......., anyone going bring dvd',
#  'comfortable room cleaned every day fresh towels even day breakfast',
#  'maybe 10yr anniversary )!! would definantly recommend',
#  'top hotel excellent location great breakfast excellent service beautiful view',
#  'x 169 rooms x say 20 weeks high season',
#  'même attendu 1 heure bien qu',
#  'perfect si tuviste una mala experiencia',
#  'unlimited vanilla custard pies ... :-) excellent gym facilities',
#  '???? ???? ????? ?????? ??????? great breakfast',
#  'kindly gave us 4 ladies travelling together 2 rooms next',
#  'gusto fue la ducha con hidromasaje',
#  'fee est très proche de free',
#  'strip ,, shops .. restaurants .. bars ,, accros',
#  'looks good ... big rooms nice roof really gentle staff',
#  'vooral de badkamer en de keuken',
#  'internet costst abot 20 euro per day',
#  'please dont bring kids ............. stay away room tip',
#  'en general una experiencia muy agradable',
#  'comfy beds great shower beautiful view good food arriving early',
#  'unfortunately dey r open fr breakfast onli',
#  'time ... good bus service visiting nearby holiday locations along',
#  'later theymade us pay 7 euro per hour',
#  'voit la publicité sur votre site',
#  'large el corte ingles department store ), change',
#  'fancy walking clean modern rooms huge beds great hairdryer breakfast',
#  'promptly indoor pool nice warm water indoor pool could benefit',
#  'lovely modern clean hotel pleasant welcoming staff great breakfast selection',
#  '5 star accomodation .... lovely room overlooking woodlands',
#  'port ... best lobster bisque ive tasted ).',
#  '.. humid air ... price eur 128 first night',
#  'hotel prestana dom joâo ii brilliant hotel',
#  'met last year greeted us back like long lost friends',
#  'good indoor swimming pool plus big outdoor swimming pool',
#  'ferugudo 5 euro one way 8 euro return',
#  'supposedly 5 star resort !! also .. another hazard',
#  'el corte de ingles five minutes walk',
#  'gardeners till 10am creating much inconvenience amoung guests',
#  'en la planta de arriba',
#  'full english ... even prosecco .. every day !!',
#  'restored within 5 minutes -- well done management !!',
#  'room decent wifi everywhere good shower pressure fabulous blackout blind',
#  'everything one could want !! also small rooftop terrace bar',
#  'choice including free champagnehotel offers excellent lunch buffet',
#  'really great chef led food welcome drink voucher good variety',
#  '4 star hotele like hdmi connections beside bed',
#  'also breakfast area feels like conference ballroom vs',
#  'many great little eateries withing short driving distance',
#  'highly energetic breakfast restaurant supervisor guy uncomfortable bed mattress',
#  'week supermarket super mercado pao quente',
#  'locally restaurants nearbynice walks friendly staff also thanks',
#  'waitresses .. bar staff ... cleaners ... general staff',
#  'lovely restaurant called dom diniz within walking distance',
#  'good bar staff made non acol cocktales',
#  'europe )- convenient hotel airport shuttle 8 per person',
#  'alvor town 20 min walk .... lovely beach walk',
#  'que fazem na casa de banho',
#  'brilliant staff great wifi air con excellent nothing really',
#  'renovation -- one couple saw cockroaches -- wi fi',
#  'ate well every night ..... would definitely go back',
#  'staff da receção não era simpatico',
#  'la proximite de la plage',
#  'one radio device could provide even better atmosfere',
#  'great location fantastic excellent room service super clean breakfast',
#  'everything !! clean spacious rooms good breakfast excellent staff',
#  'best views choose prime sea view high floor rooms',
#  'full night sleep difficult back hurting woke us',
#  'buffet style full english plus continental style meats etc',
#  'comfy bed nice roof top pool staff bit abrupt',
#  'liked :- great location near praia da rocha',
#  'el servicio muy amable que',
#  'el trato la dotación del hotel',
#  '10 euro half bottle wine 20 euro small champagne',
#  'pastries .... juices tea coffee .... cooked breakfast ....',
#  'el servicio de los recepcionistas',
#  'main squares etc lisbon 2 stops pleasant leafy area',
#  'nice hotel located near el cortes ingles',
#  'request .- guest relations contacted us numerous times throughout',
#  'excellent breakfast good spa facility warm swimming pool outside',
#  'every academy award winning feature since 1928',
#  'room spa fitness center excellent noise music every night',
#  'deluxe front sea view room ...... room 705',
#  'next time hotel da rocha !! room tip',
#  'would highly recommend cafe del mar next door',
#  'lovely reception staff could use updated yet classic uniforms',
#  'great week .. met amazing people .. fantastic base',
#  'comfy bed clean horrible towels bad location staff grumpy',
#  'got charged two euros per person per day',
#  'stayed april 2016 8 people 4 days unlimited golf',
#  'hotel shuttle bus operating 3 times per day',
#  '30 ° c outside ... :- d4',
#  '.( obridago sandra ). highly recommend vale',
#  'indoor botanic garden called estufa fria',
#  'welcome drink terrace outside bedrooms good size great location',
#  'fab location fab staff loverly weather quiet relaxing',
#  'sea view room mamma 2016 room tip',
#  'da rocha hotel http :// www',
#  'irish bars within easy walking distance ... beach',
#  'made us feel like old friends returning even though',
#  'various locations across europe within peak time school holidays',
#  'general ..... luxurious throughout .... quiet even though kids',
#  'breakfast excellent facilities gd cleanliness 1st class ...',
#  'lifts ... oh dear .. every day one',
#  'next three nights ttl 266 .--',
#  'portimao 1 euro 50 cent every 30 mins',
#  'beautiful beach .... rooms ..... fab ,,, clean',
#  'closing half board disappointed sea view restaurant closed due',
#  'good pointsvery cleanlovely lovely helpful staffweather',
#  'shops whit good food en respectabel prices',
#  '23 .. 24 .. 25 .. floor !!',
#  'hay wifi en todo el recinto',
#  'famous restaurant os arcos de campolide',
#  'beach across well maintained gardens sunny beautiful weather throughout',
#  'wonderful gelato called pizzeria la dolce vita',
#  'hospitality purposes adequately enough despite boasting boutique accommodations',
#  'monster sized beds !!) 20 mins walk',
#  'also great local restaurants within easy walking distance',
#  '5 euro return water taxi away particulary nice',
#  'mais nous étions hors saison',
#  'ex manchester untied ceo david gill',
#  'el cortes del ingles shopping centre',
#  'local lisbon specialty .. delicious ). every spread',
#  'blast ... ... could include breakfast ... arrived',
#  'impression que la navette pour l',
#  'styled van diesel pool boy one day',
#  'around cort des ingles .) ah',
#  'definitely return many thanks lee n karen',
#  'gorgeous hotelabsolutely spotlessincredibly friendly stafffree wi',
#  'best hotel quality ). admittedly bairro alto hotel',
#  'ponte 25 de abril suspension bridge',
#  'car park underground 6 euros per night extra',
#  'sky bar roof top approx 7 min walk',
#  'v good 3 star hotelwould definitely recommend',
#  'saw 5 waiting staff running around seemingly uncoordinated',
#  'really top end restaurants within five minutes walk',
#  'front desk ), two minutes later clean towels',
#  'quite dark premium room although included daily vip service',
#  'breakfast amazing top floor sea view spa great',
#  'excellent hotel lovely breakfast clean towels every day',
#  'camas eram velhas e desconfortáveis',
#  'la ubicación del hotel es excelente',
#  'account current favourable exchange rate ). lovely little beach',
#  'may get two single beds pushed together like',
#  'de spectacular ponte vasco da gama',
#  'day walking around shopping sightseeing pubcrawling taxis',
#  'classic side sea view ). ctiticisms would',
#  'lisbonsuperb locationfantastic decorationthe greatest staff polite',
#  'fancy plus free hotel computer use .- tive',
#  'need cleaned every day wifi top class loved',
#  'friendly staff ... nice clean rooms ... compact',
#  'central location near aven de libertades',
#  'great business centerwill come back next year',
#  'day .- great spa facilities opened 24 hours',
#  'well equipped rooms ... ok breakfast buffet ...',
#  'advertisments /, swimmingpool aprox 15 degree',
#  'reestablish slow wifi connection every 24 hours',
#  'hotel 5 minutes leisurely walk ... look forward',
#  'first choice .... great staff ... great hotel',
#  'venture outtown centre good half hour walk',
#  'fresh ,,,,, beds lovely comfortable ,,,,, bathroom',
#  'actually two separately made single beds pushed together',
#  'zonnetje zou veel beter zijn',
#  'hot days ). friendly helpful staff great location',
#  'bath sheets vs bath towels ... woot',
#  'corte ingles shopping centre 10 min away',
#  'make sure n visit cliff top restrauent',
#  'rock formations .... plenty fossils lying around',
#  'vanilla cake speciality ). tourist information next door',
#  'great hotel friendly staff minus one mishap everything',
#  'really nice clean complex wit really friendly staff',
#  'young handsome helpful norwegian man .. rooms',
#  '6 ), x2 large en suite jacuzzi bathrooms',
#  '40e per person without wine neither dessert',
#  '£ 142 (£ 47 per night',
#  'lovely room 12th floor beautiful views lovely food',
#  'small shops offering beautiful things .... room tip',
#  'two minutes offering unnecessary services like pouring water',
#  '50th birthday celebratory 4 day short break',
#  'massive queen size bed lovely en suite shower',
#  'first class hotel five star service waiter service',
#  'great room nice great comfy bed great shower',
#  '2 week holiday back next year !! thanks',
#  'good room good breakfast friendly responsive staff coffee',
#  'three uncomfortable kids xs twin beds lined',
#  'great location great staff beautiful beaches hotel room',
#  '18 per person .... lady called supervisor',
#  'nice quiet location entertainment every night snack bar',
#  'two two standard usb sockets providing 5vdc',
#  'roughly around 60 sunbeds !), towel monitoring',
#  'omlette guy another frying pan ... seriously slow',
#  'comfortable cantilever hammocks dotted around ... perfect',
#  'otherwise 15 euro per day per device',
#  'saying one week n tivoli matina portimao',
#  'one katarina samuel de basketball :)',
#  'amazing !! staff brilliant .. room huge spotless',
#  'find another nice restaurant called margem sul',
#  'great job good resident band called cover flow',
#  'enjoyable stay staff friendly hotel immaculatewould stay',
#  'popular 1970s revival rock n roll band',
#  'really nice proper almost chippy type sausages',
#  'lovely large towels provided ). rooms extremely comfortable',
#  'sea higher get better views less walking lower',
#  'rooms nice grounds well maintained pool area great',
#  'huge el cortes ingles department store',
#  'chocolate making facilities also fresh bottled water daily',
#  'spa )... 25 per couple per day',
#  '5 stars hotel good breakfast quite rooms although',
#  'loud coffee machine ...)- two subway stations',
#  'occupe pas de vous',
#  'photos attached location excellent beautiful beach definitely 15',
#  'bedroom townhouse booked via travel republic direct flights',
#  'much rosalinda robert jones room tip',
#  'wall mounted flat screen tv providing several channels',
#  'first floor bars close early .). gets lots',
#  'per person per day charge ), higher',
#  'wee gem overlooking sea 3 lovely older men',
#  'miraduoro de sao pedro de alcantara',
#  'lot !). modest exterior .... high standards within',
#  'rooms well maintained considering hotel 25 years old',
#  'wall wifi charge us 15 eur without information',
#  'great !!!! room spacious well maintained ladies responsible',
#  'olhos de água area nine times previously',
#  'oikein mukava hotelli aivan keskustassa',
#  'private garden views offered priva ... see',
#  'metro stop outside hotel made getting around easy',
#  'good location near marques de pombal square',
#  'mal el corte inglês',
#  'excellent metro são sebastião within easy reach',
#  'dinner within half board ), bad internet connection',
#  'excellent staff good food clean beach access poor',
#  'drink measures :-) hotel bad stuff ===========',
#  'paid euro 50 per night per person',
#  'un vienne prendre notre commande',
#  'generally overloaded ), constant electroswing music playing',
#  'good four hours leisurely walk taking fab photos',
#  'entertainment terrible bar staff ok drinks exspensive',
#  'algarve casino hotel http :// www',
#  'gigantic construction crane operating right next door',
#  'summer months despite effective air c ... see',
#  'great patio area led onto huge play area',
#  'open top bus tours making travel extremely easy',
#  'excellent blackout shades making combating jetlag',
#  'day spa visit 25 sounds like good value',
#  'avoid room 127 (& probably also 123',
#  'gym well exceeds normal hotel gym standards ).',
#  'many dishes including nice portuguese pastry etc ).',
#  'gustó fue que al final',
#  'really well located near marques de pombal',
#  'careful getting taxis portimao cab company rip offs',
#  'every portuguese hotel offersthe negativesour room',
#  'pas très loin de l',
#  'pay 2 e per day per safe',
#  'el corte inglés ). excellent breakfast',
#  'tribal floor ). staff even brought nightly sweets',
#  'unreal food smells frm streets nothing fab',
#  '8 foot square small pool staff exellent could',
#  '6 hours red eye ride without proper sleep',
#  'garden view balcony gets sun late afternoon see',
#  'seaview rooms available .... even though via internet',
#  'centauro via car trawler £ 50',
#  'otherwise u mayb giv ... see',
#  'little small 24h service great service great wine',
#  'locatio ... staff .. breakfast .. everything',
#  'small minority still evident !! bigger signs needed',
#  'fresh towels provided per person every day',
#  'visited many sheraton properties including sheraton full moon',
#  'drop crumbs !!! housekeeping kindly put ant powder',
#  'layout en ligging ver van centrum lissabon',
#  'accueil le syle le parqing',
#  'beautiful setting overlooking nice hotel overlooking stunning cliffs',
#  'hard floors means noise transmits around block',
#  'portugese traditional music .( minor things really ).',
#  'right across luis de camoes square serving',
#  'fantastic central location within easy walking distance',
#  'always fulfilled within ten minutes .- lastly',
#  'looking little restaurant opposite serving extremely good food',
#  'relatively small hotel situated atthe quietest end',
#  'hotel ), including several follow ups handled quickly',
#  'great ... especially thechef ,.. obviously',
#  'el desayuno es muy completo',
#  'main sqaure however pacoas metro station',
#  'nice feel good atmosphere comfortable room nice gym',
#  'drinks inthe room free every 24 hours',
#  'every body vert good value excellent service',
#  'el punte 25 de abril',
#  'must say well done housekeeping spotless room loved',
#  'place felt somewhat upper class come dinner time',
#  'cleaned every day fresh towels every day',
#  'good eateries within walking distance ,( adris',
#  'nice old neighborhood amid quaint hilly streets',
#  'many great restaurants within walking distance along',
#  'road ). also el corte inglés',
#  'rather naively thought everyone got one !!!',
#  'porto bay falesia provides top quality location',
#  'free shuttle service 3 times per day',
#  'quickly even though around 40 guests arrived together',
#  'praia de vale de centeanes beach',
#  '5 euros per machine ). hotel staff',
#  'quality )... must try ..... monkfish medallions',
#  'e bem limpa quando chegamos',
#  'services hospitality enthunasim helpful honist people',
#  'taxi ride away 8 euros room tip',
#  'balconybreakfast average bad points noise level high',
#  'top floor ). air con worked well',
#  'change rooms becaus ethe first rooms',
#  'lidle towns like praia da rocha',
#  'must say portimaio praia da rocha',
#  'towels every day bed made every day',
#  'sea views ... would recommend pool view',
#  'hotel da rocha next door last october',
#  'many excellent restaurants within close walking distance',
#  'restaurants within walking distance ). beach close',
#  'nice rooms decent sized cool decor good bathroom',
#  'shabby hotelshabby management great locationmore like',
#  'indoor pool good clean towels every day',
#  'full 3 euros per person service charge',
#  'many vocalists come comedians sowe sat',
#  '50 euro per hour ), table tennis',
#  'friendly staff .. nice location .. close',
#  'located directly opposite prida rocha long stretch',
#  'hard ad soft cheeses ); scrambled eggs',
#  'centre ig chic lisbonbreakfast delicious delicious',
#  'room 519 enjoys views across lagos bay',
#  '12 euro par personne per day',
#  'beautiful department store five minutes walk away',
#  '6 euro unlimited 24 hour transport ticket',
#  'new year gala dinner seating plan dispite',
#  'superb hospitality shown extremely professional discussed various wines',
#  'restaurants etc ... etc ... room tip',
#  '10 minutes ... oh yes ... roomservice',
#  'area monte santo feels really nicely spaced',
#  'bing bong ), would definitely go back',
#  'coüt 18 euros de plus !!!)',
#  'alleged "****" look extremely bad ............',
#  'regular stop near campo paqueno rail station',
#  'pastrie shop well within walking distance',
#  'amazing self catering monte santo resort apartments',
#  'room service food ... pasta dish ...',
#  'irish around pool etc every day ..',
#  'vous à attendre longtemps',
#  'pequeno almoço deveria estar incluído',
#  'well earned lazy week :) room tip',
#  'charge us extra mini bar usage ....',
#  '100 years ago .. rossio train station',
#  'traditional white apartments adorably designed throuought',
#  'oceanside views arebreathtaking !!! great value',
#  'spacious towels changed every day ... proximity',
#  '5m walking ), peaceful place room tip',
#  'busy vasco da gama shopping centre',
#  'cela amène des erreur',
#  '7 days next time .. room tip',
#  'el cuarto para nosotros',
#  'sea view room breakfast brill going back',
#  'available ..... try one per two beds',
#  'currently charge 10 per 24 hours ),',
#  'inexpensive half decent restaurant within walking distance',
#  'staff versus guest water volley ball match',
#  'great location nice pool friendly staff wifi',
#  'lovely roof top bar 12th floor understaffed',
#  'famous praca margues de pombal square',
#  'great spacious well equipped fantastic beds ..',
#  'sea view balconies fab friendly helpful staff',
#  'top floor room provides great views see',
#  'could reasonably expect plus freshly squeezed juice',
#  'på norr sidan ingen sol',
#  'local shopping mall approximately 5 minutes away',
#  'entire monte santo team offered excellent service',
#  'top notch food metro station directly outside',
#  'boundless energy ... especially harry bing bong',
#  'great central location near avenida subway station',
#  'falesia beach via pine cliffs next door',
#  'pool view 4th floor great views see',
#  'amazing views .( taxi back 18 euros',
#  'acolhimento da equipa da arquitectura',
#  'lovely little beach nearby called praia coelha',
#  'lunch menu cost 5 euro ). nb',
#  'lovely hotel ... rooms great big beds',
#  'helpful staff comfortable large king size bed',
#  'couple 2 weeks ago weather gorgous hotel',
#  'well done vivy x room tip',
#  'another local supermarket within 5 mins drive',
#  'great location near praia de rocha',
#  'pois tem porta de correr',
#  'things like wafer thin see though bacon',
#  'excellent location great tapas bat across road',
#  'great room great maid service great location',
#  'praia de vale covo public beach',
#  'great local beaches around 20 mins walk',
#  'spotlessly clean towels changed everyday beds made',
#  'praia da roche within 20 minutes',
#  'secluded beachesthe cave boat tripto eat',
#  'beach good .. 2 salt water pools',
#  'interior slightly worn outlocation excellentmore information',
#  'english pub scoobys good pub grub',
#  'pestana dom joao 11 last week bed',
#  'tadpoles swimming items floating filth built',
#  'find stunning beaches like pria grande beach',
#  'nice pool area friendly staff good value',
#  'tidy .... fresh white sheets every day',
#  '10 mins drive ). great value overall',
#  '10 yr old daughter spent several hours',
#  '5 night stay lobby loud techno music',
#  'would recommend tye hotel room tip',
#  'excellent location friendly staff continental breakfast included',
#  'harbour front .. enjoy ;) room tip',
#  'beds without top mattress ... soo hard',
#  'nice hotel good service friendly staff well',
#  'great hotel definitely worth 4 stars !!',
#  'idyllic beach around 15 mins drive away',
#  'helpful staff breakfast roof top bar design',
#  'went pretty much every night ... walking',
#  'metro station comfortable bed wifi leaking water',
#  'miss misery chops !!!! lolwe got',
#  'main restaurant area alvor 15 minutes away',
#  'main road two minutes walk away takes',
#  'praia da rocha 2 min walk',
#  'el cortes ingles department store',
#  'good holiday even better !! room tip',
#  'tie big black mercedes spotless helped us',
#  'station near jardim zoologica metro station',
#  '), vasco da gama bridgei',
#  'spotlessly clean superb food private outdoor area',
#  '00 euro public transport ticket valid 24hours',
#  'location friendly staff great breakfast choices close',
#  'would definitely come back !!! nothing !!!',
#  'italian seperating bed two single beds',
#  'buss companyabout 30 min walk form',
#  'bigger one another 10 min walk away',
#  'aggressive desk clerk told us therehad',
#  'sun sets ). breakfast offers great selection',
#  'located beside metro station near city center',
#  'lovley hotel .. entertainment really good ..',
#  'chose room service .... big mistake !....',
#  'incredible afternoon winds kept blowing debris everywhere',
#  'well appointed kitchen area .. central pools',
#  'minutes walk awayour room 2 floors',
#  'el cortes inglez shopping centre',
#  'nice location excellent friendly staff decor needs',
#  'cheese available every night .. first time',
#  '1 pacman machine ...), poor cleaning',
#  'one big beds big rooms great staff',
#  'brilliant stay would highly recommend ***** nothing',
#  'usual hot food plus pancakes cooked fresh',
#  'refunded short ... 12 days later !.',
#  'lisbon day staff friendly expensive location far',
#  'grassy area sun beds worked extremely hard',
#  'extremely friendly helpful staff room facing street',
#  'location near el cortez ingles',
#  'el corté ingles department store',
#  'great italian pizzeria within walking distance',
#  'excellent staff ,, superb kitchen chefoverall',
#  'jupiter hotel always offers first class service',
#  'breakfast service lacked selection plus food quality',
#  'spoilt ..... go sheraton lisbon room tip',
#  'good buffet breakfast great gym facilities bed',
#  'el cortes ingles shopping mall',
#  'drinks plenty lovely swimming pool good entertainment',
#  "'' jonno '' great lad breakfast",
#  'young hip crowd .. cheers .. hope',
#  'restaurant manager ), clean rooms excellent food',
#  'wednesday ... 4 course meal 16 euro',
#  'lawn onto sea attentive helpful friendly reception',
#  'soundproofed !! also extra pool beside apartment',
#  'excellent customer servicebairro alto hotel excels',
#  'corridors .... could hear everything !! breakfast',
#  'staff .. location ... comfort people standing',
#  'hotel provides many facilities including evening entertainment',
#  'great job making every guest feel special',
#  'high floor next time otherwise everything great',
#  'hotel apparently offers around 100 sun beds',
#  'location comfortable rooms modern hotel daily cleaning',
#  'really good breakfast offered also offering fruit',
#  'fishing village whilst providing many excellent restaurants',
#  'experience la joie de vivre',
#  'cold !! praia de rocha beach',
#  'site italian restaurant offers good quality food',
#  'terrffic ). plus nice beach restaurants',
#  'money friendly staff good breakfast small room',
#  'large loud dog barked constantly morning noon',
#  'glass walled bathroom !! way cool .......',
#  'seven days using two different email addresses',
#  'car park 100 metres away dining room',
#  'night time room 906 great views',
#  'even better view !! yes highly recommended',
#  'bufet diner ... stay away !!!',
#  'nice ambient fragrance like grapefruit lack',
#  'includes delicacies like roquefort ice cream',
#  'friendly perfect team help u every time',
#  'leaves etc floating around also algae around',
#  'staff watched us like hawks making',
#  'food good cocktails excellent would definitely go',
#  'one small single sized 3 drawer chest',
#  '35 year old thermosbottle ... 5star',
#  '10th floor room 1011 great room',
#  'beds really comfy best nights sleep ive',
#  'plain hot water ), well stocked bar',
#  'staff helpful wrong style room first night',
#  'ok personel friendly nice views shuttle service',
#  'staff location breakfast restaurant cleanliness quiet nothing',
#  'large reception area includes lifts right next',
#  'etc etc :-) less expensive shuttle service',
#  'body lotion ). good cable channel selection',
#  'el corte inglesias department store',
#  'location smelly beds small room smelly bathroom',
#  'handy indoor pool spa bars good breakfast',
#  'daylovely hot indoor pool like getting',
#  'however 3 large supermarkets including aldi within',
#  'well kept clean staff exceptional breakfast included',
#  'great location nice hotel limited food menu',
#  'alvor praia currenly closed due refurb',
#  'good except room service room service standards',
#  'good restaurant sol durado right across',
#  'v good kitchen dishwasher washing machine etc',
#  'small underground shopping mall 5min wolking',
#  'main road opp oceanus hotel also',
#  'main places um lisboa',
#  'brilliant location love carvario staff friendly',
#  'really helpful staff great breakfast better shower',
#  'front desk helped us book private tours',
#  'el corte ingles department store',
#  'going back soon .................... room tip',
#  'excellent ............ would defo go back',
#  'room safe froze 3 times mysteriously',
#  'nightclubs albufeira another resort along coast would',
#  'boutique 5 stars de luxe ),',
#  'helpful overall nice stay would definitely recommend',
#  'paid buffet dinner 3 times good quality',
#  'friendly staff clean terrible swell coming',
#  'change bed ., key cards also would',
#  'helpful would return nice clean room close',
#  'half price happy hour 5pm till 6pm',
#  'located around three different swimming pools see',
#  'excellent customer service thanks mrs felicidade',
#  'roof top bar could however stay open',
#  'bar staff still served us food even',
#  'near 5 start hotel proper cleaning service',
#  'wrong bed type booked double got singles',
#  'spa maybe next time would definitely return',
#  'taxi rank right outside hotel taxis waiting',
#  'runs every 20min 48hr ticket 5',
#  'g 6 euros taxi one way back',
#  'senhora da rocha ). street side',
#  'august lovely relaxing time staff lovely could',
#  'free shuttle every day running 4x',
#  'heartbeat !! best breakfast ever !! trust',
#  'comfortable rooms friendly staff superb dining experience',
#  'duo every night destroying popular songs',
#  'good view 2 entertainment absoulty terrible',
#  'gym opened 24 // 7',
#  'lot !) many thanks ). breakfast staff',
#  'luxurious 2 bedroomed apartment excellent entertainment devices',
#  'bit uneven .- bathrooms quite nicely equipped',
#  '15 euros per person per occasion',
#  'must must must book sea view room',
#  'scented corridors etc .)... highly recommended',
#  'around 4 euros one way ). depending',
#  'could also spy good sun beds',
#  'el corte ingles shopping centre',
#  'usual confused aircon panels ). friendly staff',
#  'marina view room gives immediate holiday feeling',
#  'four two adults one 12 year old',
#  'fábrica de pastel de nata',
#  'local resturants expelling fumes ). staff',
#  'spacious outdoor pool area provide ample space',
#  'jazz bar kids could run round fountain',
#  'immediate area suchas local bus services',
#  'small local mini market supplying fresh produce',
#  'good ... overall excellent experience nothing much',
#  'side 4 mtr wide raised wooden walkway',
#  'would highly recommend vale da lapa',
#  'doors inducing magnetic flux losses',
#  'breakfast poor value ... went eksewhere',
#  'good local restaurant da donato pizzeria',
#  'vale de lapa !! lovely resort',
#  'strip night club literally two doors away',
#  'good special services like free newspaper delivery',
#  'huge fantastic clean beach massive comfortable bed',
#  '£ 40 per room per night',
#  'make shift barricade ). front door',
#  'could walk ). tour buses start across',
#  'great golf break well worth budgeting',
#  'bellagio fountain view etc ). however',
#  'beautiful praia dos tres irmaos',
#  'many people hogged sun beds around',
#  'costs 10 per device per week',
#  'bought pasteis de belem .. back',
#  'also angelos bar great meal deal',
#  'room clean tidy accessible location lower corridors',
#  'reliable good solid old fashioned hotelse',
#  'offer much table service ect ... although',
#  'wet towels without giving us new ones',
#  'suite web says safety deposit box included',
#  'good location within easy walking distance',
#  'largo de dique ). next time',
#  'junior suites provide comfortable lounge seating areas',
#  'typical lisbon residential area made us wish',
#  'lovely aswell would deff go back',
#  'usual pet gripe though ..... charging 2',
#  'plastic beer cups floating ), dinner fast',
#  'alfa rooms advised us 1 month',
#  'four newly refurbished high specification rooms',
#  'location nice within easy walking distance',
#  'well done monte santo room tip',
#  'would also need two separate hotel bedrooms',
#  'stunning location fantastic room exquisite food made',
#  'big el corte ingles around',
#  'female staff wearing white blouses would',
#  'great little snack bar open till late',
#  '4 tour trips plus 48hrs use',
#  'front desk onwards simply great always willing',
#  'metro breakfast room got full rather quickly',
#  'metro stop within easy walking distance',
#  'pretty satisfied .. self service dinner consists',
#  '4th nights stay bar restaurant lacked ambience',
#  'hotel charged us almost 4 eus',
#  'everything clean except scaly shower head',
#  'july :).. thanks hf fenix nothing',
#  'must also mention erva doce cafe',
#  'extremely helpfulmarta also gave us lots',
#  'great location .., short private walk',
#  'many luxury brand shop near hotel however',
#  'jasmine bar enjoyed saturday barbecue good selection',
#  'world expo took place long time ago',
#  'nespresso machine ($ 3 per cup',
#  'modern features well equipped kitchen good ac',
#  'better use less supposedly high tech features',
#  'get superb sunsets ... please see photo',
#  'fantastic central location within walking distance',
#  'ergonomic area around hotel smelled bad',
#  'staff prepared breakfast boxes fur us',
#  'não é muito agradável',
#  'friendly young lady offered us cold beverages',
#  'given information regarding meal times room facilities',
#  'praia da rocha would certainly stay',
#  'qualidade e variedade',
#  'wonderful stay great staff especially sierranha',
#  'noticed others using .) recommend without hesitation',
#  'dinner buffets .. good salad enrrees',
#  'includes continental breakfast et wifi',
#  'recetption desk oder guest servive',
#  'sleep though ). lovely charming stairwell',
#  'car !! one bar waiter never smiled',
#  'campo paqueno bullring ), post office',
#  'modern three bedroom villas need upgrading see',
#  'perhaps hiring competent adult staff would help',
#  'superbly quiet .. one would never think',
#  'better room one got free welcome drinks',
#  'pestana dom joao ii great location',
#  'friendley staff throughout hotel particularly reception',
#  'location ... location ... location !!!',
#  'many good restaurants within walking distance',
#  'había buffet en la cena',
#  'el corte ingles ". also',
#  'bar menu could offer better food options',
#  'lobby !!!! small bath room high price',
#  'beef stroganoff etc ). warning',
#  'see two restaurants within walking distance',
#  'previous tenants ), unhelpful front desk',
#  'big train station within walking distance',
#  'wud prefer sana rex hotel wit',
#  'best long island iced tea !!',
#  'minimal kitchen equipment like pots pans etc',
#  '10 minute walk away room tip',
#  'big shopping center within walking distance',
#  '30 ° c outside ... :-',
#  '8 golfers occupied two separate apartments one',
#  'private transfer trough yellowish taxis website',
#  'overall would highly recommend monte santo',
#  'hated waterproof mattress covers ... noisy',
#  '3 metro stations within walking distance',
#  'hotel conveniently located within walking distance',
#  '13 unallocated power sockets scattered round',
#  'buffet style food gets boring quite quickly',
#  'good restaurants within 15 minutes walk',
#  'helpful breakfeast buffet poor old kettle instead',
#  'sprawling pine cliffs complex next door',
#  'daily early morning alarm call duly provided',
#  'numerous excellent restaurants within walking distance',
#  'good air con would highly recommend',
#  'poor room 906 requires new bed',
#  'paying 15 per day ). rooms',
#  'pancakes .... calorie free !.... made',
#  'porto bay hotels .. room tip',
#  'mainly reception also breakfast ordered one morning',
#  'whit portuogiese spacialities room tip',
#  'shopping area within 5 mins walk',
#  'find decent beds let alone separate bathrooms',
#  'great little pizza restaurant el pirate',
#  'comfortable room ... good air con',
#  ':) well done hotel da rocha',
#  'hotel tbm mto boa !!',
#  'u want hav trip tp lisbon',
#  'going back x x room tip',
#  'giving touristic instructions ), cleany rooms',
#  'go tp priai da rocha',
#  'bedroom furniture food outlets closed bar unattended',
#  'sofa bed could accommodate 2 additional people',
#  'per hotel standardother gud location',
#  '70eur per night wt breakfast',
#  'felt like forever pushing two prams',
#  'clear night gaze romantically upwards towards',
#  '2 singles without anti slip pads',
#  'local transport within easy walking distance',
#  'el precio es superior',
#  'two lines within 5 minutes walk',
#  'limited free wifi good signal required payment',
#  'nicely cookedthe downside .. hotel desperate',
#  'reception staff immediately made us feel relaxed',
#  'v nice way put things right quickly',
#  'costs 2 euros per half hour',
#  'missing door handles et al',
#  'villa sleeping 6 !) club house food',
#  'falessia hotel algarve portugal ok hotel',
#  'hotel lisboa lux +- 9 eur',
#  'couple two single beds pushed together',
#  'aeródromo municipal de portimão ),',
#  'never ever made us feel anything less',
#  'two single beds pushed together instead',
#  'vasco da gama shopping centre',
#  'historic center 20 minutes walking distance',
#  'nightlife lovely pool area travelled mid june',
#  'reasonably priced within 5 minutes drive',
#  'friendly polite helpful staff decor rather tired',
#  'key lisbon neighborhoods ), nice generous breakfast',
#  'restaurants galore within two minutes walk',
#  'brazilian fogo de chão ),',
#  'opened altho couldnt go onto balcony',
#  'best water park within walking distance',
#  'bit much view outstanding hotel could benefit',
#  'extremely salty chocolate lava cake dessert',
#  'campo penquo stop ). outside pool',
#  'finding mystery client trip !! cheers',
#  'personal sehr zuvorkommend und serviceorientiert',
#  'hotel bus 5 per person return',
#  'room hasnt changed one little bit',
#  'highgienic sink got blocked breakfast staff',
#  'early evening although bar prices quite expensive',
#  'meant kids could run around outside safely',
#  'set lunch 3 course waiter served lunch',
#  'good great location 10 mins walk',
#  '20 per pers per day',
#  'website said 1and half hour transfer',
#  'sausages bacon eggs tomatoes mushrooms hashbrowns',
#  'plate away whilst youre still chewing',
#  'previous ta reviews said lower ones overlooking',
#  'big shopping center el cortes',
#  'portugal :- 15 euro cab ride',
#  '!). lovely harbour within walking distance',
#  'hotel da rocha 21 may 2016',
#  'always stayed ifn ferragudo yet tivoli',
#  'helpful front desk staff room tip',
#  'five min walk away ... bread',
#  'friendly helpful staff ... great location',
#  'twice monte santo gave us lifts',
#  'modern conveniences including flat screen tv',
#  'looking closer youll see broken flagging',
#  'excellent week away :-) room tip',
#  'request within 5 minutes !. breakfast',
#  'shabby james villa near praia gale',
#  'real pain ... small little bottle fridge',
#  'excellent location .. highly recommended !!!',
#  'serious cleaning issue central air condition meaning',
#  '3 euro uber ). room tip',
#  'go back next year room tip',
#  'chargeable 2 eur per use ...',
#  'everything within 3 mins .. bars',
#  'bar every night untill around midnight',
#  'location !!! location !!! location !!!',
#  'nice hotel less accurate trip info offered',
#  'paid approx £ 90 per night',
#  'helpful n wud order ur taxi',
#  'restaurant cost 22 euros per person',
#  'two occasions à la carte',
#  '45 euro deal including unlimited use',
#  'walking distance called come priva',
#  'portuguese channels showed north american tv shows',
#  'already flat 50 inches tv screen',
#  'lovely beach )! 5 minute walk',
#  'beware !, check prices firstwe left',
#  'returning next year !! room tip',
#  'cycling etc ). olhus de agua',
#  'veg option dessert always 2 optionsyou',
#  'loud mouth attention seeking guests mainly women',
#  'great beaches within 10 mins drive',
#  '1 english channellast friday 22nd july',
#  '3rd floor sea view room overlooking',
#  'directly opposite sao sebastian metro station',
#  'location ... especially staff ... breakfast',
#  'city center near campo pequeno arena',
#  'cleaned every daywe stayed half board',
#  'five including two year old twins',
#  'towels etc ,. changed every day',
#  'safety deposit box £ 169',
#  'mid november within easy walking distance',
#  'pastel de belem ". incredible stay',
#  'hate two small beds pushed together',
#  'great sea view great breakfast selection',
#  '2 minute free bus ride available',
#  'large pool view room spotlessly clean',
#  'three bed roomed villa number 33',
#  'great week .. would recommend vitors',
#  'cheese fruits jams bread toast coffee etc',
#  'bed reasonably comfortable ... excellent location',
#  'directly opposite sao sebastiao metro stop',
#  'two blocks away underneath campo pequeno',
#  'great time breakfast top notch room',
#  '20 min walk along cliff walk',
#  'sea view rooms ... well worth',
#  'diy holiday without ant waiter service',
#  '!!! food eas excellent .... room',
#  'old cream mercedes please avoid !!!',
#  '24 hour pass costing 13 euros',
#  'luna alvor bay hotel last year',
#  '5th floor sea view room staff',
#  'boyfriend visited baia grande last year',
#  'clean great location friendly staff rooms',
#  'sitting .. fab pool .. entertainment',
#  'well maintained .. luke warm selection',
#  '23e per room per night',
#  'also freshly squeezed orange juice provided',
#  'bad smell 2nd room poor renovations quality',
#  'nice top notch double room overlooking',
#  'v good breakfast ... would recommend',
#  'nice spacious room .. friendly staff',
#  'great high powered hair dryers !!!',
#  'friendly staff !!! nice location !!!!',
#  'good beaches 20 mins walk away',
#  'pleasant 20 minute tree lined walk',
#  'great hotel great location great breakfast',
#  'reasonably priced high quality shellfish ).',
#  'air conditioning units within arms reach',
#  'get panache back next year together',
#  'dishwasher ), large king size bedroom',
#  'calling three times got dental kits',
#  'upper floor sea view room see',
#  'upper floor side sea view room',
#  'roof top bar called side bar',
#  'cama e que se vê',
#  'airport 5 euro cab ride however',
#  'comfortable king sized bed breakfast offered',
#  'back next year !! fantastic location',
#  'prosecco every morning !!! pool area',
#  'good location good staff great breakfast',
#  'staff versus guests water polo match',
#  '2 floors underground like dungeon ..',
#  'king size bed staff location nothing',
#  'leaving clean pool towels every day',
#  'get small restaurants within 10 minutes',
#  '2 days without fresh air ...',
#  'new straw parasol type sun shades',
#  'hotel charges 19 eur per day',
#  'comfortable bed ad clean slow check',
#  'big hotel located 5 minutes walk',
#  'sea view higher floor room see',
#  'july 7th till16th best holiday ever',
#  'fresh squeezed orange juice 4 types',
#  '9am till 9pm ... 1 euro',
#  '9 nights rooms cleaned every day',
#  'friendly staff beautiful room great location',
#  'menu er received one week ago',
#  'go back next year .... thanks',
#  'twin beds pushed together especially since',
#  'sheraton pine cliffs hotel next door',
#  'hot .. praia du vau',
#  'great location great room clean large',
#  'always got one within 5 minutes',
#  'ideal 202 ,- 2 ... see',
#  '15min per child !! seriously ..',
#  'quite position within 15 minutes drive',
#  'got two twins shoved together ...',
#  'one free wifi user per room',
#  'great hotel !! great location right',
#  'lighting controls area bit mmysterious especially',
#  'bali green beauty salon amazing staff',
#  'ground floor .... room 124 ...',
#  '50th !). roof top pool area',
#  'beach praia vale de covo',
#  'choose high floor sea view see',
#  'whose lovely persona boded well',
#  'scramble eggs ). easy walking around',
#  'helpful staff comfortable bed great location',
#  'well equipped rooms ... cleaned daily',
#  'clean hotel .. nice breakfast rooms',
#  'con unit ).. overall minor things',
#  'older guests obviously liked seeing children around',
#  'two minute walk ... pretty much',
#  'job well done !!!! room tip',
#  'good breakfast including gluten free bread',
#  '7 ???????? culdent fault anything',
#  'top floor giving fantastic views across',
#  'fantastic white sandy beach within 200m',
#  '10 min walking ), perfect full',
#  'shopping centre fab every thing fab',
#  'relaxing last minute 5 day stay',
#  ...]
